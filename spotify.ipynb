# %%
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib.pyplot import subplots

# %%
spotify = pd.read_csv('../data/spotify_churn_dataset.csv')
spotify
# Out:
#       user_id  gender  age country subscription_type  listening_time  \
# 0           1  Female   54      CA              Free              26
# 1           2   Other   33      DE            Family             141
# 2           3    Male   38      AU           Premium             199
# 3           4  Female   22      CA           Student              36
# 4           5   Other   29      US            Family             250
# ...       ...     ...  ...     ...               ...             ...
# 7995     7996   Other   44      DE           Student             237
# 7996     7997    Male   34      AU           Premium              61
# 7997     7998  Female   17      US              Free              81
# 7998     7999  Female   34      IN           Student             245
# 7999     8000   Other   45      AU              Free             210
#
#       songs_played_per_day  skip_rate device_type  ads_listened_per_week  \
# ...

# %%
# Questions:
# What countries are most of the users from?
# What is the most common subscrition type?
# Do users with the free subscrition listen to less music? Do they tend to skip songs less
# Do men or women listen to more music
# What is the spread of ages?
# What is the gender demographic? (pie chart)

# %%
plt.boxplot(spotify["age"])
plt.title("Ages")
plt.ylabel("Years")
plt.show()

# %%
unique_countries = spotify['country'].unique()
print(unique_countries)
# Out:
# ['CA' 'DE' 'AU' 'US' 'UK' 'IN' 'FR' 'PK']

# %%
frequency = spotify['country'].value_counts()

plt.bar(frequency.index, frequency.values)
plt.title("Users by Country")
plt.xlabel("Country")
plt.ylabel("Number of Users")
plt.show()

# %%
# 3 box plots for each subscription type
free =  spotify[spotify["subscription_type"] == "Free"]["listening_time"].dropna()
student = spotify[spotify["subscription_type"] == "Student"]["listening_time"].dropna()
family = spotify[spotify["subscription_type"] == "Family"]["listening_time"].dropna()
premium = spotify[spotify["subscription_type"] == "Premium"]["listening_time"].dropna()

plt.title("Listening Time By Subscription Type")
plt.boxplot([free, student, family, premium], tick_labels=["Free", "Student", "Family", "Premium"])
plt.ylabel("Listening Time (Min)")
plt.show()

# %%
free =  spotify[spotify["subscription_type"] == "Free"]["songs_played_per_day"].dropna()
student = spotify[spotify["subscription_type"] == "Student"]["songs_played_per_day"].dropna()
family = spotify[spotify["subscription_type"] == "Family"]["songs_played_per_day"].dropna()
premium = spotify[spotify["subscription_type"] == "Premium"]["songs_played_per_day"].dropna()

plt.title("Songs Played By Subscription Type")
plt.boxplot([free, student, family, premium], tick_labels=["Free", "Student", "Family", "Premium"])
plt.ylabel("Songs Played")
plt.show()

# %%
free =  spotify[spotify["subscription_type"] == "Free"]["skip_rate"].dropna()
student = spotify[spotify["subscription_type"] == "Student"]["skip_rate"].dropna()
family = spotify[spotify["subscription_type"] == "Family"]["skip_rate"].dropna()
premium = spotify[spotify["subscription_type"] == "Premium"]["skip_rate"].dropna()

plt.title("Skip Rate By Subscription Type")
plt.boxplot([free, student, family, premium], tick_labels=["Free", "Student", "Family", "Premium"])
plt.ylabel("Skip Rate")
plt.show()

# %%
category_counts = spotify['gender'].value_counts()

category_counts.plot(kind='pie', autopct='%1.1f%%', figsize=(4, 4))
plt.title('Gender Demographics of Users')
plt.ylabel('') # Hide the y-axis label for a cleaner pie chart
plt.show()

# %%
spotify
# Out:
#       user_id  gender  age country subscription_type  listening_time  \
# 0           1  Female   54      CA              Free              26
# 1           2   Other   33      DE            Family             141
# 2           3    Male   38      AU           Premium             199
# 3           4  Female   22      CA           Student              36
# 4           5   Other   29      US            Family             250
# ...       ...     ...  ...     ...               ...             ...
# 7995     7996   Other   44      DE           Student             237
# 7996     7997    Male   34      AU           Premium              61
# 7997     7998  Female   17      US              Free              81
# 7998     7999  Female   34      IN           Student             245
# 7999     8000   Other   45      AU              Free             210
#
#       songs_played_per_day  skip_rate device_type  ads_listened_per_week  \
# ...
